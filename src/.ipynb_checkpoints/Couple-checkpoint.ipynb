# %%
import sys
import spotpy, pandas
import sobek, wflow

# %%
"""
File and folder structure suggested:
- This file as a script or as a jupyter file
- setup.ini configuration vars for coupling
- Sobek:
    - (Full model folders) default MagSec1, ...2, ...3
    - sobek.py
- Wflow
    - (Full model folders) default wflow_0, ....
    - wflow.py
- Notes: Sobek need be running and import network click to scratch!
"""

class Couple:    
    def __init__(self):
        #Define some useful vars
        self.timeserie = pandas.date_range('2008-01-01', '2012-12-31', freq='D')
        #self.runtss_path = "Wflow/wflow_0/CORMA_data/run0001/run.tss"
        #self.lateralfile_path="Sobek/MagSect%d.lit/%d/LATERAL.DAT"
        self.runtss_path = "debug/run.tss"
        self.lateralfile_path="debug/LATERAL.DAT"
        #Start wflow calibration process
        self.runTss = self.wflow_init()
        self.couple_init()
        
    def wflow_init(self):
        try:
            sampler = spotpy.algorithms.mc(wflow.spot_setup(), dbname='wflow_calibration', dbformat='csv')
            param = sampler.getdata.parameters()
            runTss = wflow.spot_setup.single_simulation(param)
            return runTss
        except:
            sys.exit("something wrong happened!")

    def sobek_init(self):
        pass
    
    def couple_init(self):
        """
        Setup.ini filename
        This method is for setup the static files of Sobek inputs (Laterals and boundarys)
        with the output of wflow Run.tss file.
        """
        self.setup = open("setup.ini","r")
        self.setup = self.setup.readlines()
        valid1 = self.change_lateral_values(1, eval(c.setup[1].strip()))
        valid2 = self.change_lateral_values(2, eval(c.setup[2].strip()))
        valid3 = self.change_lateral_values(3, eval(c.setup[3].strip()))
        if valid1 == valid2 == valid3 == "success": pass
        else: sys.exit("something wrong happened!")
        #Run sobek calibration algorithm
        self.sobek_init()
        
    def change_lateral_values(self, M, V):
        """
        M: number of Sobek model, Int
        V: id_sobel: Number_wflow, Dictionary Python
        Case: Sobel case number, Int
        """
        self.V = V
        #Transform from run.tss to LATERAL.DAT
        """
        self.runTss = pandas.read_table(self.runtss_path,
                                    skiprows=[i for i in range(35)], 
                                    #sep="|\s*", 
                                    #engine="python", 
                                    delim_whitespace=True,
                                    header=None)
        """
        if M == 1:
            Case=10
            #lateral = open(self.lateralfile_path%(M,Case))
            lateral = open(self.lateralfile_path)
            lateral_data = [self.runTss[:][V[v]] for idx,v in enumerate(V)]
            
        elif M == 2:
            Case = 4
            #lateral = open(self.lateralfile_path%(M,Case))
            lateral = open(self.lateralfile_path)
            lateral_data = [self.runTss[:][V[v]] for idx,v in enumerate(V)]
            
        elif M == 3:
            Case = 3
            #lateral = open(self.lateralfile_path%(M,Case))
            lateral = open(self.lateralfile_path, "w")
            lateral_data = [self.runTss[:][V[v]] for idx,v in enumerate(V)]
            #Write the new Laterals.dat
            for i in self.timeserie:
                print ""
        return "success"

# %%
c = Couple()
c.couple_init()
# Out:
# {'Rio_Luisa': 12, 'Rio_Recio': 18, 'Rio_Aipe': 7, 'Rio_Sumapaz': 13, 'Rio_Villavieja': 6, 'Rio_Bogota': 14, 'Rio_Prado': 10, 'Rio_Totare': 17, 'Rio_Cabrera': 9, 'Rio_Coello': 15, 'Rio_Bache': 5, 'Rio_Saldana': 11, 'Rio_Lagunilla': 19, 'Rio_Pata': 8, 'Rio_Guarino': 21, 'Rio_Seco': 16, 'Rio_Guali': 20}
# {'Rio_Santo_Domingo': 32, 'Rio_Opon': 29, 'Rio_Cimitarra': 31, 'Rio_Nare': 26, 'Rio_Ermitano': 25, 'Rio_La_Miel': 22, 'Rio_Sogamoso': 30, 'Rio_Lebrija': 33, 'Rio_Cocorna': 24, 'Rio_Carare': 28, 'Rio_San_Bartolome': 27, 'Rio_Negro': 23}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-c83d75d615ed> in <module>()
#       1 c = Couple()
# ----> 2 c.couple_init()
#
# <ipython-input-24-144b1a8b060f> in couple_init(self)
#      42         self.setup = self.setup.readlines()
#      43         valid1 = self.change_lateral_values(1, eval(c.setup[1].strip()))
# ---> 44         valid2 = self.change_lateral_values(2, eval(c.setup[2].strip()))
#      45         valid3 = self.change_lateral_values(3, eval(c.setup[3].strip()))
#      46         if valid1 == valid2 == valid3 == "success": pass
#
# <ipython-input-24-144b1a8b060f> in change_lateral_values(self, M, V)
#      75             #lateral = open(self.lateralfile_path%(M,Case))
#      76             lateral = open(self.lateralfile_path)
# ---> 77             lateral_data = [self.runTss[:][V[v]] for idx,v in enumerate(V)]
#      78
#      79         elif M == 3:
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6610)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6554)()
#
# KeyError: 33

# %%
for idx,v in enumerate(c.V):
    print c.runTss[:][c.V[v]]
# Out:
# 35
# 39
# 38
# 42
# 36
# 41
# 34
# 37
# 40

# %%
# Out:
# <bound method DataFrame.head of         0        1             2             3         4             5   \
# 0        1  48.2378  1.000000e+31  1.000000e+31  1.517790  1.000000e+31
# 1        2  52.3653  1.000000e+31  1.000000e+31  1.555900  1.000000e+31
# 2        3  50.8108  1.000000e+31  1.000000e+31  1.499890  1.000000e+31
# 3        4  48.4316  1.000000e+31  1.000000e+31  1.442860  1.000000e+31
# 4        5  45.9743  1.000000e+31  1.000000e+31  1.381110  1.000000e+31
# 5        6  43.3879  1.000000e+31  1.000000e+31  1.325770  1.000000e+31
# 6        7  41.7601  1.000000e+31  1.000000e+31  1.278120  1.000000e+31
# 7        8  43.3638  1.000000e+31  1.000000e+31  1.301840  1.000000e+31
# 8        9  41.5046  1.000000e+31  1.000000e+31  1.306910  1.000000e+31
# 9       10  38.8574  1.000000e+31  1.000000e+31  1.293010  1.000000e+31
# 10      11  36.3583  1.000000e+31  1.000000e+31  1.260330  1.000000e+31
# 11      12  36.2092  1.000000e+31  1.000000e+31  1.221240  1.000000e+31
# 12      13  36.5498  1.000000e+31  1.000000e+31  1.185370  1.000000e+31
# 13      14  35.5374  1.000000e+31  1.000000e+31  1.147830  1.000000e+31
# 14      15  37.1118  1.000000e+31  1.000000e+31  1.358910  1.000000e+31
# 15      16  36.9133  1.000000e+31  1.000000e+31  1.522390  1.000000e+31
# 16      17  35.2790  1.000000e+31  1.000000e+31  1.693280  1.000000e+31
# 17      18  32.8093  1.000000e+31  1.000000e+31  1.660610  1.000000e+31
# 18      19  30.2134  1.000000e+31  1.000000e+31  1.582880  1.000000e+31
# 19      20  27.7155  1.000000e+31  1.000000e+31  1.561760  1.000000e+31
# 20      21  25.3625  1.000000e+31  1.000000e+31  1.496980  1.000000e+31
# 21      22  23.6965  1.000000e+31  1.000000e+31  1.422070  1.000000e+31
# 22      23  21.6935  1.000000e+31  1.000000e+31  1.348530  1.000000e+31
# 23      24  21.5159  1.000000e+31  1.000000e+31  1.294970  1.000000e+31
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-fa7a26c2dfe7> in <module>()
# ----> 1 lateral_data = [c.runTss[:][c.V[v]-1] for idx,v in enumerate(c.V)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/dist-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6610)()
#
# pandas/hashtable.pyx in pandas.hashtable.Int64HashTable.get_item (pandas/hashtable.c:6554)()
#
# KeyError: 34

# %%
c.V["Rio_Bache"]
# Out:
# 5

# %%
c.runTss[:][:12]
# Out:
#     0        1             2             3        4             5   \
# 0    1  48.2378  1.000000e+31  1.000000e+31  1.51779  1.000000e+31
# 1    2  52.3653  1.000000e+31  1.000000e+31  1.55590  1.000000e+31
# 2    3  50.8108  1.000000e+31  1.000000e+31  1.49989  1.000000e+31
# 3    4  48.4316  1.000000e+31  1.000000e+31  1.44286  1.000000e+31
# 4    5  45.9743  1.000000e+31  1.000000e+31  1.38111  1.000000e+31
# 5    6  43.3879  1.000000e+31  1.000000e+31  1.32577  1.000000e+31
# 6    7  41.7601  1.000000e+31  1.000000e+31  1.27812  1.000000e+31
# 7    8  43.3638  1.000000e+31  1.000000e+31  1.30184  1.000000e+31
# 8    9  41.5046  1.000000e+31  1.000000e+31  1.30691  1.000000e+31
# 9   10  38.8574  1.000000e+31  1.000000e+31  1.29301  1.000000e+31
# 10  11  36.3583  1.000000e+31  1.000000e+31  1.26033  1.000000e+31
# 11  12  36.2092  1.000000e+31  1.000000e+31  1.22124  1.000000e+31
#
#               6             7             8             9       ...       \
# 0   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 1   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 2   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 3   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 4   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 5   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 6   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 7   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 8   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 9   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 10  1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
# 11  1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31      ...
#
#               23            24            25            26        27       28  \
# 0   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31  1021.400  151.868
# 1   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31  1142.210  155.387
# 2   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31  1140.930  152.573
# 3   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31  1107.060  148.650
# 4   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31  1066.820  144.620
# 5   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31  1026.310  140.668
# 6   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31   988.364  136.834
# 7   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31   980.930  133.534
# 8   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31   969.473  130.153
# 9   1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31   958.346  126.711
# 10  1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31   933.627  123.321
# 11  1.000000e+31  1.000000e+31  1.000000e+31  1.000000e+31   901.045  120.050
#
#               29            30       31            32
# 0   1.000000e+31  1.000000e+31  146.331  1.000000e+31
# 1   1.000000e+31  1.000000e+31  171.616  1.000000e+31
# 2   1.000000e+31  1.000000e+31  175.484  1.000000e+31
# 3   1.000000e+31  1.000000e+31  171.474  1.000000e+31
# 4   1.000000e+31  1.000000e+31  165.223  1.000000e+31
# 5   1.000000e+31  1.000000e+31  158.325  1.000000e+31
# 6   1.000000e+31  1.000000e+31  151.303  1.000000e+31
# 7   1.000000e+31  1.000000e+31  145.076  1.000000e+31
# 8   1.000000e+31  1.000000e+31  139.912  1.000000e+31
# 9   1.000000e+31  1.000000e+31  134.296  1.000000e+31
# 10  1.000000e+31  1.000000e+31  128.068  1.000000e+31
# 11  1.000000e+31  1.000000e+31  121.684  1.000000e+31
#
# [12 rows x 33 columns]

# %%
c.V.keys()
# Out:
# ['Rio_Luisa',
#  'Rio_Recio',
#  'Rio_Aipe',
#  'Rio_Sumapaz',
#  'Rio_Villavieja',
#  'Rio_Bogota',
#  'Rio_Prado',
#  'Rio_Totare',
#  'Rio_Cabrera',
#  'Rio_Coello',
#  'Rio_Bache',
#  'Rio_Saldana',
#  'Rio_Lagunilla',
#  'Rio_Pata',
#  'Rio_Guarino',
#  'Rio_Seco',
#  'Rio_Guali']

# %%
import pandas as pd 
times = pd.date_range('2008-01-01', '2012-12-31', freq='D')

# %%
times[0]
# Out:
# Timestamp('2008-01-01 00:00:00', offset='D')
